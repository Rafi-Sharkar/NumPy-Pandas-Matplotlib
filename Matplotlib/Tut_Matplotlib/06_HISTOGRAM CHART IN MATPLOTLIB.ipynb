# %% [markdown]
# # Histogram plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x = np.random.randint(10,60,50)
print(x)
# Out:
# [39 19 51 55 29 58 23 12 21 44 17 28 36 19 16 53 26 56 32 59 14 53 21 13
#  47 45 22 24 30 51 56 32 58 52 10 58 28 30 57 17 47 42 34 59 51 24 54 47
#  16 33]

# %%
x= [23, 18, 39, 33, 14, 29, 58, 12, 43, 36, 26, 40, 32, 47, 37, 42, 40, 42, 27, 11, 34, 21, 40, 59,
 35, 47, 35, 13, 26, 14, 29, 35, 20, 37, 22, 25, 41, 22, 19, 41, 23, 47, 37, 52, 27, 17, 57, 24,
 11, 19]

l = [10,20,30,40,50,60,70]
plt.hist(x, "auto",(0,100),edgecolor="r", log=True, rwidth=.7)

plt.title("RS Plot")
plt.xlabel("Python")
plt.ylabel("No")

plt.show()

# %%
l = [10,20,30,40,50,60,70]

plt.hist(x, edgecolor="r")

plt.title("RS Plot")
plt.xlabel("Python")
plt.ylabel("No")

plt.axvline(40, color="y",label="line")


plt.show()
