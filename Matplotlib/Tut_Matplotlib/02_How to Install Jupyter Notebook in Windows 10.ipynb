# %% [markdown]
# # Why Jupyter notebook ?
# ### Jupyter notebook provide ous Good graphial interface and cell system to run spesific block of code

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.randint(5, 30, 10)
y = np.random.randint(5, 30, 10)

plt.bar(x,y)

plt.show()
